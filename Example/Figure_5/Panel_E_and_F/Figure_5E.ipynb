# %%
import os
os.chdir("D:/文章返修/source data/Figure_5/Panel_E")
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import OrderedDict
import pandas as pd

# %%
file_dir = "./"

dict_gene_2 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_382 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27759)),
 ('ORF7b', (27756, 27847)),
 ('delta_7b_8', (27848, 28229)),
 ('ORF8', (28230, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_346 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 27910)),
 ('delta_8', (27910, 28254)),
 ('ORF8_2', (28254, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_188 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28002)),
 ('delta_8', (28003, 28190)),
 ('ORF8_2', (28191, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_142 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27759)),
 ('ORF7b', (27756, 27846)),
 ('delta_7b_8', (27847, 27984)),
 ('ORF8', (27985, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_133 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27759)),
 ('ORF7b', (27756, 27826)),
 ('delta_7b_8', (27827, 27959)),
 ('ORF8', (27960, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_90 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27759)),
 ('ORF7b', (27756, 27807)),
 ('delta_7b_8', (27808, 27897)),
 ('ORF8', (27898, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_62 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 27903)),
 ('delta_8', (27904, 27965)),
 ('ORF8_2', (27965, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_186 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27503)),
 ('delta_ORF7a', (27504, 27689)),
 ('ORF7a2', (27690, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_220 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27472)),
 ('delta_7a', (27472, 27672)),
 ('ORF7a2', (27673, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_171 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27518)),
 ('delta_ORF7a', (27519, 27689)),
 ('ORF7a2', (27690, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_207 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27518)),
 ('delta_ORF7a', (27519, 27725)),
 ('ORF7a2', (27726, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_154 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27530)),
 ('delta_ORF7a', (27531, 27684)),
 ('ORF7a2', (27685, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_116 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27535)),
 ('delta_ORF7a', (27536, 27651)),
 ('ORF7a2', (27652, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_92 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27554)),
 ('delta_ORF7a', (27555, 27646)),
 ('ORF7a2', (27647, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_78 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27562)),
 ('delta_ORF7a', (27563, 27640)),
 ('ORF7a2', (27641, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

dict_gene_50 = OrderedDict([
 ('ORF6', (27250, 27387)),
 ('gap_6_7a', (27388, 27393)),
 ('ORF7a', (27394, 27620)),
 ('delta_ORF7a', (27621,27670)),
 ('ORF7a2', (27671, 27759)),
 ('ORF7b', (27756, 27887)),
 ('gap_7b_8', (27888, 27893)),
 ('ORF8', (27894, 28259)),
 ('gap_8_N', (28260, 28273)),
 ('N', (28274, 29533)),
 ('gap_N_ORF10', (29534, 29557)),
 ('ORF10', (29558, 29650))])

res = 1000
color = ['lightgreen','lightgreen', 'pink', 'lightblue', 'pink', 'pink', 'lightblue', 'lightblue', 'lightblue', 'lightblue', 'pink', 'lightblue', 'lightblue', 'lightblue']
color_345 = ['lightblue', 'lightblue', 'lightblue', 'lightblue', 'lightblue', 'pink', 'lightblue', 'lightblue', 'lightblue']

genome_id = ['382', '346', '188', '142','133','90', '62', '220',
             '186', '171', '207', '154', '116', '92', '78', '50']
list_id = [ '346','220', '188','62','186', '171', '207', '154', '116', '92', '78', '50']

# %%
strc_ric_sars2_virion = np.loadtxt( file_dir + 'virus.phase4_final.whole.ct', usecols=[0,1,2,3,4,5], dtype=[('1','<i4'),('2','<U2'),('3','<i4'),('4','<i4'),('5','<i4'), ('6','<i4')], skiprows=1)

rna_seq_24_all = np.loadtxt(file_dir + '2_beta_SARS-CoV-2-9_all-rep-rna.1nt.none.matrix', usecols=[0,1,2], dtype=[('S','<f8'),('E','<f8'),('value','<f8')])

# %%
recom_strc = np.zeros(strc_ric_sars2_virion.shape[0], dtype=[('S', '<i4'), ('E', '<i4'), ('value', '<f8')])
recom_strc['S'] = strc_ric_sars2_virion['1']
recom_strc['E'] = strc_ric_sars2_virion['5']
recom_strc['value'] = strc_ric_sars2_virion['5']
recom_strc_hp = recom_strc[recom_strc['value']>0]
recom_strc_hp['value'] = 100

recom_data = rna_seq_24_all #recom_strc_hp #
distance = recom_data['E'] - recom_data['S']
recom_data_long = recom_data[distance >= 100]
recom_data_short = recom_data[distance <= 1000]
recom_data_highq = recom_data_short[ recom_data_short['value'] > 20]
start = 27790
end = 28229 + 50 #end = 29550 #
target_seq_1 = recom_data_long[ (recom_data_long['S'] > start) & (recom_data_long['E'] < end)]
start = 27472 - 30
end = 27760
target_seq_2 = recom_data_long[ (recom_data_long['S'] > start) & (recom_data_long['E'] < end)]
color_reads = plt.get_cmap('Greys')( np.linspace( 0.4, 0.8, int( np.log2( max(target_seq_1['value'].max(), target_seq_2['value'].max() ) ) ) + 1 ) )
color_reads_hq = plt.get_cmap('Greys')(np.linspace(0.1, 0.9, int(np.log2(recom_data_highq['value'].max())) + 1))

# %%
with pd.ExcelWriter("non-canonical junctions.xlsx", engine='openpyxl') as writer:
    for i, arr in enumerate([target_seq_1, target_seq_2]):
        pd.DataFrame(arr).to_excel(writer, sheet_name=f"Sheet{i+1}", 
                                    index=False, header=False)

# %%
fig = plt.figure(figsize=(14,8))
# plt.subplot(211)
i = 6
for key in dict_gene_2:
    s,e = dict_gene_2[key]
    s = s / res
    e = e / res
    if key.split('_')[0] == 'gap':
        plt.plot([s,e],[0,0], color = 'black', alpha = 0.5)
        
    else:
        plt.fill_between([s,e],[0.05,0.05], -0.05, color = color[i], alpha = 0.5)
        i += 1

for id_seq in ['1','2']:
    target_seq = locals()['target_seq_' + id_seq]
    for seq in target_seq[:]:
        s = seq[0] / res
        e = seq[1] / res
        r = (e - s) / 2
        a,b = ((s+e)/2, 0.05)
        value = int(np.log2(seq[2]))
        x = np.arange(a - r, a + r, 0.0001 )
        y = b + np.sqrt(r ** 2 - (x - a) ** 2)
        plt.plot(x , y, color = color_reads[value], lw = 0.15, alpha = 0.5)

up = -0.07
for id_g in genome_id:
    genome = locals()['dict_gene_' + id_g]
    i = 6
    if id_g in list_id:
         color_genome = color_345
         i = 0
    else :
        color_genome = color
    for key in genome:
        s,e = genome[key]
        s = s / res
        e = e / res    
        down = up - 0.1
        mid = (up + down) / 2
        if key.split('_')[0] == 'gap':
            plt.plot([s,e],[mid, mid], color = 'black', alpha = 0.5)
            
        elif key.split('_')[0] == 'delta':
             plt.plot([s,e],[mid, mid], color = 'red', alpha = 0.5)    
             
        else:
            plt.fill_between([s,e],[up, up], down, color = color_genome[i], alpha = 0.5)
            i += 1
    up = down - 0.02

second = recom_strc_hp[(recom_strc_hp['S'] > 27250) & (recom_strc_hp['E'] < 29550)]
for seq in second[second['S'] < second['E']]:
    s = seq[0] / res
    e = seq[1] / res
    r = (e - s) / 2
    a,b = ((s+e)/2, down)
    value = int(np.log2(seq[2]))
    x = np.arange(a - r, a + r, 0.0001 )
    y = b + np.sqrt(r ** 2 - (x - a) ** 2)
    plt.plot(x , -y + down*2, color = color_reads_hq[value], lw = 0.15)   

plt.xlim(27.25, 29.65)
plt.ylim(-3.125, 0.35)
plt.xticks([27.25, 28.05, 28.85, 29.65])
plt.yticks([])
ax = plt.gca()
ax.spines[['left', 'right', 'top']].set_visible(False)
# Out:
# C:\Users\11509\AppData\Local\Temp\ipykernel_6408\3424823126.py:24: RuntimeWarning: invalid value encountered in sqrt
#   y = b + np.sqrt(r ** 2 - (x - a) ** 2)
# C:\Users\11509\AppData\Local\Temp\ipykernel_6408\3424823126.py:61: RuntimeWarning: invalid value encountered in sqrt
#   y = b + np.sqrt(r ** 2 - (x - a) ** 2)
